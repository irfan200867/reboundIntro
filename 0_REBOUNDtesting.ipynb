# %%
# !pip install -U rebound
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.6/709.6 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -U reboundx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for reboundx: filename=reboundx-3.11.0-cp310-cp310-linux_x86_64.whl size=270394 sha256=4d1ad35a20850d4994853c41f6969106e0056beaa45f3cdbe78b25865afebf9a
#   Stored in directory: /root/.cache/pip/wheels/95/82/33/11630d2138c3aca767e9c97b86b84af348f9ad91da1939d417
# Successfully built reboundx
# ...

# %%
import rebound

# %%
sim = rebound.Simulation()

# %%
sim = None
